# %% [markdown]
# # Video Game Dataset Analysis
# ### An exploration of video game sales from 1980 to 2020
# The data can be found on Kaggle at [this link](https://www.kaggle.com/datasets/gregorut/videogamesales)

# %% [markdown]
# <img src="pacman.webp" width=800>

# %% [markdown]
# <img src="consolespic.png" width=600>

# %% [markdown]
# ### Table of Contents
#
# Step 1: [Data and Library Import](#Step-1:-Data-and-Library-Import)
#
# Step 2: [Dataset Examination](#Step-2:-Dataset-Examination)
#
# Step 3: [Feature Engineering](#Step-3:-Feature-Engineering)
#
# Step 4: [Exploratory Data Analysis](#Step-4:-Exploratory-Data-Analysis)
#
# [1) Publisher Performance](#1\)-Publisher-Performance)
#
# [2) Genre Performance](#2\)-Genre-Performance)
#
# [3) Year Performance](#3\)-Year-Performance)
#
# [4) Platform Performance](#4\)-Platform-Performance)
#
# [5) Sales Performance](#5\)-Sales-Performance)
#
# [5a) Publisher Sales Performance](#5a\)-Publisher-Sales-Performance)
#
# [5b) Genre Sales Performance](#5b\)-Genre-Sales-Performance)
#
# [5c) Year Sales Performance](#5c\)-Year-Sales-Performance)
#
# [5d) Platform and Game Sales Performance](#5d\)-Platform-and-Game-Sales-Performance)
#
# [5e) Region Sales Performance](#5e\)-Region-Sales-Performance)

# %% [markdown]
# ## Step 1: Data and Library Import

# %%
#Import modules and read dataset
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
import seaborn as sns

with open("vgsales.csv", "r") as f:
    df = pd.read_csv(f)

# %% [markdown]
# ## Step 2: Dataset Examination

# %%
#Set options for float format and display max columns

pd.set_option('display.float_format', lambda x: '%.2f' %x)
#pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii 2006.00        Sports  Nintendo
# 1     2         Super Mario Bros.      NES 1985.00      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii 2008.00        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii 2009.00        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB 1996.00  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
#Examine number of rows and columns
df.shape
# Out:
# (16598, 11)

# %%
#Examine data types and null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
#Summary statistics for quantitative features
df.describe()
# Out:
#           Rank     Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# count 16598.00 16327.00  16598.00  16598.00  16598.00     16598.00
# mean   8300.61  2006.41      0.26      0.15      0.08         0.05
# std    4791.85     5.83      0.82      0.51      0.31         0.19
# min       1.00  1980.00      0.00      0.00      0.00         0.00
# 25%    4151.25  2003.00      0.00      0.00      0.00         0.00
# 50%    8300.50  2007.00      0.08      0.02      0.00         0.01
# 75%   12449.75  2010.00      0.24      0.11      0.04         0.04
# max   16600.00  2020.00     41.49     29.02     10.22        10.57
#
#        Global_Sales
# count      16598.00
# mean           0.54
# std            1.56
# min            0.01
# 25%            0.06
# 50%            0.17
# 75%            0.47
# max           82.74

# %%
#Unique values for Platform
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
#Unique values for Year
print(sorted(df['Year'].unique()))
# Out:
# [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2020]

# %%
#Number of unique values for Year
df['Year'].nunique()
# Out:
# 39

# %%
#Unique values for Genre
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
#Examine null values
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <ul>
#     <li>There are some Null values in the Year and Publisher columns</li>
#         <ul>
#         <li>These values only make up a small percentage of the total number of observations so it's ok to drop them</li>
#     </ul>
#     <li>The Year column's data type is float, let's change that to int or datetime</li>
# </ul>
# </div>

# %% [markdown]
# ## Step 3: Feature Engineering

# %% [markdown]
# ### Isolating the Null values

# %%
#Create and examine variable for Year null values
yearnan = df[df['Year'].isnull()].reset_index()
yearnan
# Out:
#      index   Rank                         Name Platform  Year         Genre  \
# 0      179    180              Madden NFL 2004      PS2   NaN        Sports
# 1      377    378             FIFA Soccer 2004      PS2   NaN        Sports
# 2      431    432   LEGO Batman: The Videogame      Wii   NaN        Action
# 3      470    471   wwe Smackdown vs. Raw 2006      PS2   NaN      Fighting
# 4      607    608               Space Invaders     2600   NaN       Shooter
# ..     ...    ...                          ...      ...   ...           ...
# 266  16307  16310                Freaky Flyers       GC   NaN        Racing
# 267  16327  16330                    Inversion       PC   NaN       Shooter
# 268  16366  16369  Hakuouki: Shinsengumi Kitan      PS3   NaN     Adventure
# 269  16427  16430                 Virtua Quest       GC   NaN  Role-Playing
# 270  16493  16496                   The Smurfs      3DS   NaN        Action
#
#                                   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0                           Electronic Arts      4.26      0.26      0.01
# 1                           Electronic Arts      0.59      2.36      0.04
# 2    Warner Bros. Interactive Entertainment      1.86      1.02      0.00
# 3                                       NaN      1.57      1.02      0.00
# 4                                     Atari      2.36      0.14      0.00
# ..                                      ...       ...       ...       ...
# 266                                 Unknown      0.01      0.00      0.00
# 267                      Namco Bandai Games      0.01      0.00      0.00
# 268                                 Unknown      0.01      0.00      0.00
# 269                                 Unknown      0.01      0.00      0.00
# 270                                 Unknown      0.00      0.01      0.00
#
#      Other_Sales  Global_Sales
# 0           0.71          5.23
# 1           0.51          3.49
# 2           0.29          3.17
# 3           0.41          3.00
# 4           0.03          2.53
# ..           ...           ...
# 266         0.00          0.01
# 267         0.00          0.01
# 268         0.00          0.01
# 269         0.00          0.01
# 270         0.00          0.01
#
# [271 rows x 12 columns]

# %%
#Create and examine variable for Publisher null values
pubnan = df[df['Publisher'].isnull()].reset_index()
pubnan
# Out:
#     index   Rank                                               Name Platform  \
# 0     470    471                         wwe Smackdown vs. Raw 2006      PS2
# 1    1303   1305                                     Triple Play 99       PS
# 2    1662   1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA
# 3    2222   2224                                 Bentley's Hackpack      GBA
# 4    3159   3161  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 5    3166   3168  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 6    3766   3768  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 7    4145   4147                                 Sonic the Hedgehog      PS3
# 8    4526   4528  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 9    4635   4637  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 10   5302   5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii
# 11   5647   5649  Cartoon Network Collection: Game Boy Advance V...      GBA
# 12   6272   6274  The Legend of Zelda: The Minish Cap(weekly JP ...      GBA
# 13   6437   6439           Sonic X: Game Boy Advance Video Volume 1      GBA
# 14   6562   6564  Dora the Explorer: Game Boy Advance Video Volu...      GBA
# 15   6648   6650  Cartoon Network Collection: Game Boy Advance V...      GBA
# 16   6849   6851     All Grown Up!: Game Boy Advance Video Volume 1      GBA
# 17   7208   7210  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 18   7351   7353                     Yu Yu Hakusho: Dark Tournament      PS2
# 19   7470   7472  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 20   7953   7955                   Thomas the Tank Engine & Friends      GBA
# 21   8330   8332    Dragon Ball GT: Game Boy Advance Video Volume 1      GBA
# 22   8341   8343  Codename: Kids Next Door: Game Boy Advance Vid...      GBA
# 23   8368   8370  Teenage Mutant Ninja Turtles: Game Boy Advance...      GBA
# 24   8503   8505                                       Stronghold 3       PC
# 25   8770   8772  Cartoon Network Collection: Game Boy Advance V...      GBA
# 26   8848   8850  Pokémon: Johto Photo Finish: Game Boy Advance ...      GBA
# 27   8896   8898  Strawberry Shortcake: Game Boy Advance Video V...      GBA
# 28   9517   9519                             Farming Simulator 2011       PC
# 29   9749   9751  Super Robot Wars OG Saga: Masou Kishin II - Re...      PSP
# 30  10382  10384                   Disney Channel Collection Vol. 1      GBA
# 31  10494  10496             Atsumare! Power Pro Kun no DS Koushien       DS
# 32  11076  11078                       Action Man-Operation Extreme       PS
# 33  11526  11528  Cartoon Network Collection: Game Boy Advance V...      GBA
# 34  12487  12489                               Chou Soujuu Mecha MG       DS
# 35  12517  12519       Prinny: Can I Really Be The Hero? (US sales)      PSP
# 36  13278  13280                     Monster Hunter Frontier Online      PS3
# 37  13672  13674                          B.L.U.E.: Legend of Water       PS
# 38  13962  13964                                     World of Tanks     X360
# 39  14087  14089                                       Housekeeping       DS
# 40  14296  14299                                Bikkuriman Daijiten       DS
# 41  14311  14314                                      Silverlicious       DS
# 42  14698  14701                                 UK Truck Simulator       PC
# 43  14942  14945  Umineko no Naku Koro ni San: Shinjitsu to Gens...      PS3
# 44  15056  15059                                            Xia-Xia       DS
# 45  15261  15264                                       Mario Tennis      3DS
# 46  15325  15328  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 47  15353  15356                   Demolition Company: Gold Edition       PC
# 48  15788  15791  Moshi, Kono Sekai ni Kami-sama ga Iru to suru ...      PSV
# 49  15915  15918                                       Dream Dancer       DS
# 50  16191  16194                    Homeworld Remastered Collection       PC
# 51  16198  16201             AKB1/48: Idol to Guam de Koishitara...     X360
# 52  16208  16211  Super Robot Monkey Team: Game Boy Advance Vide...      GBA
# 53  16229  16232                        Brothers in Arms: Furious 4     X360
# 54  16367  16370                                  Dance with Devils      PSV
# 55  16494  16497                    Legends of Oz: Dorothy's Return      3DS
# 56  16543  16546                             Driving Simulator 2011       PC
# 57  16553  16556                                     Bound By Flame     X360
#
#       Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0      NaN      Fighting       NaN      1.57      1.02      0.00         0.41
# 1      NaN        Sports       NaN      0.81      0.55      0.00         0.10
# 2  2007.00          Misc       NaN      0.87      0.32      0.00         0.02
# 3  2005.00          Misc       NaN      0.67      0.25      0.00         0.02
# 4  2004.00          Misc       NaN      0.46      0.17      0.00         0.01
# 5  2004.00          Misc       NaN      0.46      0.17      0.00         0.01
# 6  2004.00          Misc       NaN      0.38      0.14      0.00         0.01
# 7      NaN      Platform       NaN      0.00      0.48      0.00         0.00
# 8  2004.00          Misc       NaN      0.31      0.11      0.00         0.01
# 9  2004.00          Misc       NaN      0.30      0.11      0.00         0.01
# 10     NaN        Action       NaN      0.15      0.05      0.14         0.01
# 11 2005.00          Misc       NaN      0.23      0.08      0.00         0.01
# 12     NaN        Action       NaN      0.00      0.00      0.27         0.01
# 13 2004.00          Misc       NaN      0.19      0.07      0.00         0.00
# 14 2004.00          Misc       NaN      0.18      0.07      0.00         0.00
# 15 2004.00          Misc       NaN      0.18      0.07      0.00         0.00
# 16 2004.00          Misc       NaN      0.17      0.06      0.00         0.00
# 17 2004.00          Misc       NaN      0.16      0.06      0.00         0.00
# 18     NaN      Fighting       NaN      0.10      0.08      0.00         0.03
# 19 2004.00          Misc       NaN      0.15      0.05      0.00         0.00
# 20 2004.00     Adventure       NaN      0.13      0.05      0.00         0.00
# 21 2004.00          Misc       NaN      0.12      0.05      0.00         0.00
# 22 2004.00          Misc       NaN      0.12      0.05      0.00         0.00
# 23 2004.00          Misc       NaN      0.12      0.04      0.00         0.00
# 24 2011.00      Strategy       NaN      0.06      0.10      0.00         0.00
# 25 2005.00          Misc       NaN      0.11      0.04      0.00         0.00
# 26 2004.00          Misc       NaN      0.11      0.04      0.00         0.00
# 27 2004.00          Misc       NaN      0.11      0.04      0.00         0.00
# 28 2010.00    Simulation       NaN      0.00      0.13      0.00         0.00
# 29     NaN      Strategy       NaN      0.00      0.00      0.12         0.00
# 30 2004.00          Misc       NaN      0.08      0.03      0.00         0.00
# 31     NaN        Sports       NaN      0.00      0.00      0.10         0.00
# 32     NaN        Action       NaN      0.05      0.03      0.00         0.01
# 33 2004.00          Misc       NaN      0.06      0.02      0.00         0.00
# 34     NaN    Simulation       NaN      0.00      0.00      0.06         0.00
# 35     NaN        Action       NaN      0.06      0.00      0.00         0.00
# 36     NaN  Role-Playing       NaN      0.00      0.00      0.05         0.00
# 37     NaN     Adventure       NaN      0.00      0.00      0.04         0.00
# 38     NaN       Shooter       NaN      0.00      0.03      0.00         0.00
# 39     NaN        Action       NaN      0.00      0.00      0.04         0.00
# 40     NaN          Misc       NaN      0.00      0.00      0.03         0.00
# 41 2012.00        Action       NaN      0.03      0.00      0.00         0.00
# 42 2010.00    Simulation       NaN      0.00      0.03      0.00         0.00
# 43     NaN     Adventure       NaN      0.00      0.00      0.02         0.00
# 44 2012.00      Platform       NaN      0.00      0.02      0.00         0.00
# 45     NaN        Sports       NaN      0.00      0.00      0.02         0.00
# 46 2005.00          Misc       NaN      0.01      0.01      0.00         0.00
# 47 2011.00    Simulation       NaN      0.00      0.02      0.00         0.00
# 48 2016.00     Adventure       NaN      0.00      0.00      0.02         0.00
# 49     NaN          Misc       NaN      0.01      0.00      0.00         0.00
# 50     NaN      Strategy       NaN      0.00      0.01      0.00         0.00
# 51     NaN          Misc       NaN      0.00      0.00      0.01         0.00
# 52 2005.00          Misc       NaN      0.01      0.00      0.00         0.00
# 53     NaN       Shooter       NaN      0.01      0.00      0.00         0.00
# 54 2016.00        Action       NaN      0.00      0.00      0.01         0.00
# 55 2014.00        Puzzle       NaN      0.00      0.01      0.00         0.00
# 56 2011.00        Racing       NaN      0.00      0.01      0.00         0.00
# 57 2014.00  Role-Playing       NaN      0.00      0.01      0.00         0.00
#
#     Global_Sales
# 0           3.00
# 1           1.46
# 2           1.21
# 3           0.93
# 4           0.64
# 5           0.64
# 6           0.53
# 7           0.48
# 8           0.43
# 9           0.42
# 10          0.35
# 11          0.32
# 12          0.27
# 13          0.27
# 14          0.26
# 15          0.25
# 16          0.24
# 17          0.22
# 18          0.21
# 19          0.21
# 20          0.19
# 21          0.17
# 22          0.17
# 23          0.17
# 24          0.16
# 25          0.15
# 26          0.15
# 27          0.15
# 28          0.13
# 29          0.12
# 30          0.11
# 31          0.10
# 32          0.09
# 33          0.08
# 34          0.06
# 35          0.06
# 36          0.05
# 37          0.04
# 38          0.04
# 39          0.04
# 40          0.03
# 41          0.03
# 42          0.03
# 43          0.02
# 44          0.02
# 45          0.02
# 46          0.02
# 47          0.02
# 48          0.02
# 49          0.02
# 50          0.01
# 51          0.01
# 52          0.01
# 53          0.01
# 54          0.01
# 55          0.01
# 56          0.01
# 57          0.01

# %% [markdown]
# ### Dropping Null values

# %%
#Drop null values
df = df.dropna(how='any', axis=0)

# %%
#Check that all null values have been dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Changing the datatype for Year

# %%
#Assign Year as int 
df['Year'] = df['Year'].astype(int)

# %%
#Check Year data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  int64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# <div class="alert alert-success">
#   <strong>Summary of Actions</strong>
#     <li>All Null values have been dropped</li>
#     <li>Since we only have a year measurement for time, there's no reason to use the datetime library. Int will be a sufficient data type for our analysis.</li>
# </div>

# %% [markdown]
# ## Step 4: Exploratory Data Analysis

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Analysis Plan</strong>
#     <h6>Let's break up the analysis into 5 main parts:</h6>
#     <ol>
#         <li>Publisher Performance</li>
#         <li>Genre Performance</li>
#         <li>Year Performance</li>
#         <li>Platform Performance</li>
#         <li>Sales Performance</li>
#   </ol>
# </div>

# %% [markdown]
# # 1) Publisher Performance

# %% [markdown]
# ### Who were the Top 10 Publishers and how many games did they make?

# %%
#Create quick table of top 10 Publishers
df['Publisher'].value_counts().head(10)
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
# THQ                              712
# Nintendo                         696
# Sony Computer Entertainment      682
# Sega                             632
# Take-Two Interactive             412
# Name: Publisher, dtype: int64

# %%
#Create variable for top 10 Publishers
top_10_pubs = df.groupby(['Publisher'])['Publisher'].count().sort_values(ascending=False).head(10)
top_10_pubs
# Out:
# Publisher
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
# THQ                              712
# Nintendo                         696
# Sony Computer Entertainment      682
# Sega                             632
# Take-Two Interactive             412
# Name: Publisher, dtype: int64

# %%
#Horizontal bar chart of top 10 Publishers
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
top_10_pubs.plot(kind='barh', width=0.6, edgecolor='k')
plt.xlabel('Number of Games', fontsize=18)
plt.ylabel('Publisher Name', fontsize=18)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.title('Number of Games from Top 10 Publishers (1980 - 2020)', fontsize=22)
plt.show()

# %% [markdown]
# ### What were the top 10 most prolific years for publishers and how many games did they make?

# %%
#Create variable for top 10 most prolific years for publishers
top_10_pub_year = df.groupby(['Year', 'Publisher'])

# %%
#Create quick table for publishers and the amount of games they released that year
t10py = top_10_pub_year['Publisher'].size().sort_values(ascending=False).head(10)
t10py
# Out:
# Year  Publisher
# 2009  Activision         121
# 2008  Electronic Arts    120
# 2005  Electronic Arts    117
# 2008  Ubisoft            112
# 2009  Electronic Arts    112
# 2007  Electronic Arts    107
# 2006  Electronic Arts    102
# 2009  Ubisoft            102
# 2010  Activision          89
# 2008  Activision          88
# Name: Publisher, dtype: int64

# %%
#Horizontal bar chart of top 10 most prolific years for publishers
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
t10py.plot(kind='barh', width=0.7, edgecolor='k')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Number of Games', fontsize=18)
plt.ylabel('Year and Publisher', fontsize=18)
plt.title('Top 10 Prolific Publishers and Their Most Prolific Years', fontsize=22)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>Electronic Arts and Activision were the top game publishers during this period</li>
#     <li>However, the most prolific years all came at the end of the 2000's and were dominated by EA, Activision, and Ubisoft</li>
# </div>

# %% [markdown]
# # 2) Genre Performance

# %% [markdown]
# ### What were the top 10 Genres?

# %%
#Create quick table of top Genre value counts
df['Genre'].value_counts().head(10)
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Name: Genre, dtype: int64

# %%
#Create table of Genre value counts on a percentage basis
df['Genre'].value_counts(normalize=True)
# Out:
# Action         0.20
# Sports         0.14
# Misc           0.10
# Role-Playing   0.09
# Shooter        0.08
# Adventure      0.08
# Racing         0.08
# Platform       0.05
# Simulation     0.05
# Fighting       0.05
# Strategy       0.04
# Puzzle         0.03
# Name: Genre, dtype: float64

# %% [markdown]
# ### How many games of each genre are there?

# %%
#Create variable for number of games by Genre 
top_genres = df.groupby(['Genre'])['Genre'].count().sort_values(ascending=False)
top_genres
# Out:
# Genre
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %%
#Horizontal bar chart for top 10 genres
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
top_genres.plot(kind='barh', width=0.6, edgecolor='k')
plt.xlabel('Number of Games', fontsize=14)
plt.ylabel('Genre', fontsize=14)
plt.title('Top 10 Genres', fontsize=22)
#plt.tight_layout()
plt.show()

# %%
#Pie chart for Genre
vc = df['Genre'].value_counts()
labels = vc.index

plt.figure(figsize=(8,8), facecolor='gold')
colors = ['deepskyblue', 'dodgerblue', 'lightskyblue', 'royalblue', 'cornflowerblue']
plt.pie(df['Genre'].value_counts(), labels=labels, colors=colors, autopct='%1.2f%%', pctdistance=.8)
plt.title('Percentage of Games by Genre (All)', fontsize=22)
plt.show()

# %% [markdown]
# ### Which genres saw the most releases in a given year? (Top 10)

# %%
#Create variable to group by Year
top_10_year_genre = df.groupby(['Year'])

# %%
#Create variable to further group by Genre
t10yg = top_10_year_genre['Genre'].value_counts().sort_values(ascending=False).head(10)

# %%
#Bar chart of most released Genres in a single year
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
t10yg.plot(kind='bar', width=0.8, edgecolor='k')
plt.xticks(fontsize=11, rotation=60)
plt.xlabel('Year and Genre', fontsize=16)
plt.ylabel('Number of Games', fontsize=16)
plt.title('Most Released Genre, Top 10 Years', fontsize=22)
plt.show()

# %%
#Create variable for number of most amount of games by Genre  
top_genre_year = df.groupby(['Year','Genre']).size().sort_values(ascending=False).reset_index(name='Count').head(5)
#top_genre_year = top_genre_year.rename(columns={0:'Number of Games'})
top_genre_year
# Out:
#    Year   Genre  Count
# 0  2009  Action    272
# 1  2012  Action    265
# 2  2015  Action    255
# 3  2011  Action    239
# 4  2010  Action    226

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>Action, Sports, Misc, and RPGs account for more than half of all games.</li>
#     <li>Action games were consistently the most released genre in years where the most games were released except for a couple where Misc games were.</li>
# </div>

# %% [markdown]
# # 3) Year Performance

# %% [markdown]
# ### What Years Had the Most Releases?

# %%
#Create quick table of Year value counts
df['Year'].value_counts()
# Out:
# 2009    1431
# 2008    1428
# 2010    1257
# 2007    1201
# 2011    1136
# 2006    1008
# 2005     936
# 2002     829
# 2003     775
# 2004     744
# 2012     655
# 2015     614
# 2014     580
# 2013     546
# 2001     482
# 1998     379
# 2000     349
# 2016     342
# 1999     338
# 1997     289
# 1996     263
# 1995     219
# 1994     121
# 1993      60
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1989      17
# 1983      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# 2017       3
# 2020       1
# Name: Year, dtype: int64

# %%
#Create variable for Year value counts
top_10_years = df.groupby(['Year'])['Year'].count().sort_values(ascending=False).head(10).astype(int)
top_10_years
# Out:
# Year
# 2009    1431
# 2008    1428
# 2010    1257
# 2007    1201
# 2011    1136
# 2006    1008
# 2005     936
# 2002     829
# 2003     775
# 2004     744
# Name: Year, dtype: int64

# %%
#Horizontal bar chart for years with the most game releases
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
top_10_years.plot(kind='barh', width=0.6, edgecolor='k')
plt.xlabel('Number of Games', fontsize=16)
plt.ylabel('Year', fontsize=16)
plt.title('Top Years for Game Releases', fontsize=22)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>The 2000s (but especially the latter half) saw the highest number of game releases, in addition to 2011.</li>
# </div>

# %% [markdown]
# # 4) Platform Performance

# %% [markdown]
# ### Which Platforms Had the Most Games?

# %%
#Create quick table for Platform value counts
df['Platform'].value_counts()
# Out:
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# GC       542
# 3DS      499
# PSV      410
# PS4      336
# N64      316
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
#Create variable for Platform value counts
top_platforms = df.groupby(['Platform'])['Platform'].count().sort_values(ascending=False).head(10)
top_platforms
# Out:
# Platform
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# Name: Platform, dtype: int64

# %%
#Horizontal bar chart for number of games released for the top Platforms
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
top_platforms.plot(kind='barh', width=0.6, edgecolor='k')
plt.xlabel('Number of Games', fontsize=16)
plt.ylabel('Platform', fontsize=16)
plt.title('Number of Games Released by Platform', fontsize=22)
plt.show()

# %%
#Bar chart for number of games released for the top Platforms
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
top_platforms.plot(kind='bar', width=0.6, edgecolor='k')
plt.xticks(rotation=0)
plt.xlabel('Number of Games', fontsize=14)
plt.ylabel('Platform', fontsize=14)
plt.title('Number of Games Released by Platform', fontsize=15)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>Nintendo DS and Playstation 2 had nearly double the amount of games as their closest competitors.</li>
# </div>

# %% [markdown]
# # 5) Sales Performance

# %% [markdown]
# ### 5a) Publisher Sales Performance

# %%
#Create variable for total Global Sales by Publisher
top_pub_sales = df.groupby(['Publisher'])['Global_Sales'].sum().sort_values(ascending=False).reset_index().head(10)
top_pub_sales
# Out:
#                       Publisher  Global_Sales
# 0                      Nintendo       1784.43
# 1               Electronic Arts       1093.39
# 2                    Activision        721.41
# 3   Sony Computer Entertainment        607.28
# 4                       Ubisoft        473.54
# 5          Take-Two Interactive        399.30
# 6                           THQ        340.44
# 7  Konami Digital Entertainment        278.56
# 8                          Sega        270.70
# 9            Namco Bandai Games        253.65

# %%
#Bar chart for all time top selling Publishers
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
plt.bar(top_pub_sales['Publisher'], top_pub_sales['Global_Sales'], width=0.8, edgecolor='k')
plt.xticks(fontsize=11, rotation=60)
plt.xlabel('Publisher', fontsize=16)
plt.ylabel('Sales (in Millions of $)', fontsize=16)
plt.title('Top Selling Publishers (1980-2020)', fontsize=22)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>Nintendo handily outsold all other publishers, while Electronic Arts is the only other publisher to gross over $1 Billion worldwide.</li>
# </div>

# %% [markdown]
# ### 5b) Genre Sales Performance

# %%
#Create variable for total Global Sales by Genre
genre_sales = df.groupby(['Genre'])['Global_Sales'].sum().sort_values(ascending=False).reset_index()
genre_sales
# Out:
#            Genre  Global_Sales
# 0         Action       1722.84
# 1         Sports       1309.24
# 2        Shooter       1026.20
# 3   Role-Playing        923.83
# 4       Platform        829.13
# 5           Misc        789.87
# 6         Racing        726.76
# 7       Fighting        444.05
# 8     Simulation        389.98
# 9         Puzzle        242.21
# 10     Adventure        234.59
# 11      Strategy        173.27

# %%
#Bar chart for total Global Sales by Genre
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
plt.bar(genre_sales['Genre'], genre_sales['Global_Sales'], width=0.8, edgecolor='k')
plt.xticks(fontsize=11)
plt.xlabel('Genre', fontsize=14)
plt.ylabel('Sales (in Millions of $)', fontsize=16)
plt.title('Total Sales by Genre (1980-2020)', fontsize=22)
plt.show()

# %%
#Create variable for comparing Sales by region
comp_genre = df[['Genre', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
comp_genre_map = comp_genre.groupby(by=['Genre']).sum()

# %%
#Create heatmap comparing Sales across regions by Genre 
plt.figure(figsize=(15,10))
sns.set(font_scale=2)
sns.heatmap(comp_genre_map, annot=True, fmt='.1f')

plt.xlabel('Region')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Comparison of Sales across Regions and Genres', fontsize=28)
plt.show()

# %%
#Create variable for top genres by Year
top_10_year_genre_sales = df.groupby(['Year', 'Genre'])

# %%
#Create variable for Global sales by Year and Genre 
t10ygs = top_10_year_genre_sales['Global_Sales'].sum().sort_values(ascending=False).head(10)
t10ygs
# Out:
# Year  Genre
# 2009  Action    139.36
#       Sports    138.52
# 2008  Action    136.39
# 2006  Sports    136.16
# 2013  Action    125.22
# 2012  Action    122.01
# 2011  Action    118.96
# 2010  Action    117.64
# 2007  Action    106.50
# 2011  Shooter    99.36
# Name: Global_Sales, dtype: float64

# %%
#Horizontal bar chart for highest grossing genres and their release year
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
t10ygs.plot(kind='barh', width=0.7, edgecolor='k')
plt.xticks(fontsize=11, rotation=60)
plt.xlabel('Sales (in Millions of $)', fontsize=14)
plt.ylabel('Genre and Year', fontsize=14)
plt.title('Top 10 Highest Grossing Genres and Their Release Year', fontsize=22)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>Action games far outsell any other genre, followed by Sports games and then Shooters.</li>
#     <li>Action games are also the biggest sellers in most regions except in Japan where RPGs sell more.</li>
#     <li>In terms of highest grossing years, Action games were typically the best seller with Sports games taking two of the top ten spots and Shooters taking one.</li>
# </div>

# %% [markdown]
# ### 5c) Year Sales Performance

# %%
#Summary statistics for Global Sales
df['Global_Sales'].describe()
# Out:
# count   16291.00
# mean        0.54
# std         1.57
# min         0.01
# 25%         0.06
# 50%         0.17
# 75%         0.48
# max        82.74
# Name: Global_Sales, dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>It looks the IQR for Global Sales is betweeen 0.06 and .48 but the max is 82.74. Sounds like we've got a fair amount of outliers.</li>
#     </div>

# %%
#Boxplot for Global Sales
df['Global_Sales'].plot(kind='box')

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>This is difficult to read due to several outliers. Let's try to make it more informative by filtering the data.</li>
#     </div>

# %%
#Create a subset of the data where Global Sales are fewer than $10 million
df1 = df[df['Global_Sales'] < 10]

# %%
#Examine row count of new dataframe
df1.shape
# Out:
# (16229, 11)

# %%
#Summary statistics for the new subset of Global Sales
df1['Global_Sales'].describe()
# Out:
# count   16229.00
# mean        0.47
# std         0.89
# min         0.01
# 25%         0.06
# 50%         0.17
# 75%         0.47
# max         9.88
# Name: Global_Sales, dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>Even when filtering the data down to max global sales of &dollar;10 Million the number of observations and the IQR have barely changed.</li>
#     </div>

# %%
#Boxplot of Global Sales
df1['Global_Sales'].plot(kind='box')

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>This plot looks better, but it looks like we need to filter it down even further.</li>
#     </div>

# %%
#Create a subset of the data where Global Sales are fewer than $2 million
df2 = df[df['Global_Sales'] < 2]

# %%
df2['Global_Sales'].plot(kind='box')

# %%
df2.shape
# Out:
# (15450, 11)

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>We've cut down the data to include only observations that have &dollar;2,000,000 or less in global sales, which is still 15,450 games.</li>
#     <li>The overwhelming majority of games don't clear &dollar;1,000,000 in global sales.</li>
#     <li>This could be because there are games from as far back as 1980 when video games weren't as popular as they are today.</li>
#     </div>

# %%
sorted(df['Year'].unique())
# Out:
# [1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2020]

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>Let's bisect this into pre- and post-2000 to see how games have sold over time.</li>
#     </div>

# %%
pre2000 = df[df['Year'] < 2000]
pre2000
# Out:
#         Rank                           Name Platform  Year         Genre  \
# 1          2              Super Mario Bros.      NES  1985      Platform
# 4          5       Pokemon Red/Pokemon Blue       GB  1996  Role-Playing
# 5          6                         Tetris       GB  1989        Puzzle
# 9         10                      Duck Hunt      NES  1984       Shooter
# 12        13    Pokemon Gold/Pokemon Silver       GB  1999  Role-Playing
# ...      ...                            ...      ...   ...           ...
# 16379  16382             Grand Prix Legends       PC  1997        Racing
# 16436  16439                        Worms 2       PC  1997      Strategy
# 16506  16509  Samurai Shodown: Warrios Rage       PS  1999      Fighting
# 16554  16557              Psychic Detective       PS  1995     Adventure
# 16583  16586                 Carmageddon 64      N64  1999        Action
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 1                Nintendo     29.08      3.58      6.81         0.77
# 4                Nintendo     11.27      8.89     10.22         1.00
# 5                Nintendo     23.20      2.26      4.22         0.58
# 9                Nintendo     26.93      0.63      0.28         0.47
# 12               Nintendo      9.00      6.18      7.20         0.71
# ...                   ...       ...       ...       ...          ...
# 16379       Vivendi Games      0.00      0.01      0.00         0.00
# 16436          Microprose      0.00      0.01      0.00         0.00
# 16506                 SNK      0.01      0.00      0.00         0.00
# 16554     Electronic Arts      0.01      0.00      0.00         0.00
# 16583  Virgin Interactive      0.01      0.00      0.00         0.00
#
#        Global_Sales
# 1             40.24
# 4             31.37
# 5             30.26
# 9             28.31
# 12            23.10
# ...             ...
# 16379          0.01
# 16436          0.01
# 16506          0.01
# 16554          0.01
# 16583          0.01
#
# [1974 rows x 11 columns]

# %%
post2000 = df[df['Year'] >= 2000]
post2000
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 6          7                             New Super Mario Bros.       DS  2006
# 7          8                                          Wii Play      Wii  2006
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
#           Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0        Sports    Nintendo     41.49     29.02      3.77         8.46
# 2        Racing    Nintendo     15.85     12.88      3.79         3.31
# 3        Sports    Nintendo     15.75     11.01      3.28         2.96
# 6      Platform    Nintendo     11.38      9.23      6.50         2.90
# 7          Misc    Nintendo     14.03      9.20      2.93         2.85
# ...         ...         ...       ...       ...       ...          ...
# 16593  Platform       Kemco      0.01      0.00      0.00         0.00
# 16594   Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595    Racing  Activision      0.00      0.00      0.00         0.00
# 16596    Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597  Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        Global_Sales
# 0             82.74
# 2             35.82
# 3             33.00
# 6             30.01
# 7             29.02
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [14317 rows x 11 columns]

# %%
post2000['Global_Sales'].plot(kind='box')

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>Even in the 2000s there still seems to be a fair amount of outliers.</li>
#     </div>

# %%
post2000.sort_values(by='Global_Sales', ascending=False)
# Out:
#         Rank                                             Name Platform  Year  \
# 0          1                                       Wii Sports      Wii  2006
# 2          3                                   Mario Kart Wii      Wii  2008
# 3          4                                Wii Sports Resort      Wii  2009
# 6          7                            New Super Mario Bros.       DS  2006
# 7          8                                         Wii Play      Wii  2006
# ...      ...                                              ...      ...   ...
# 16182  16185                                  Princess Arthur      PSP  2013
# 16183  16186                      Sakura-Sou no Pet na Kanojo      PSP  2013
# 16184  16187  Fatal Fury: Battle Archives Volume 2 (JP sales)      PS2  2007
# 16185  16188           Tantei Jinguuji Saburo: Hai to Diamond      PSP  2009
# 16597  16600                                 Spirits & Spells      GBA  2003
#
#            Genre         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0         Sports          Nintendo     41.49     29.02      3.77         8.46
# 2         Racing          Nintendo     15.85     12.88      3.79         3.31
# 3         Sports          Nintendo     15.75     11.01      3.28         2.96
# 6       Platform          Nintendo     11.38      9.23      6.50         2.90
# 7           Misc          Nintendo     14.03      9.20      2.93         2.85
# ...          ...               ...       ...       ...       ...          ...
# 16182       Misc      Idea Factory      0.00      0.00      0.01         0.00
# 16183  Adventure    Kadokawa Games      0.00      0.00      0.01         0.00
# 16184   Fighting      SNK Playmore      0.00      0.00      0.01         0.00
# 16185  Adventure  Arc System Works      0.00      0.00      0.01         0.00
# 16597   Platform           Wanadoo      0.01      0.00      0.00         0.00
#
#        Global_Sales
# 0             82.74
# 2             35.82
# 3             33.00
# 6             30.01
# 7             29.02
# ...             ...
# 16182          0.01
# 16183          0.01
# 16184          0.01
# 16185          0.01
# 16597          0.01
#
# [14317 rows x 11 columns]

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>Just scrolling through the data we can see that there are only 62 games that sold more than &dollar;10,000,000 globally.</li>
#     </div>

# %%
post2000['Global_Sales'].describe()
# Out:
# count   14317.00
# mean        0.50
# std         1.47
# min         0.01
# 25%         0.06
# 50%         0.16
# 75%         0.45
# max        82.74
# Name: Global_Sales, dtype: float64

# %%
post2000.shape
# Out:
# (14317, 11)

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>It also looks like most of the games in this dataset came out during and after the year 2000 (14,317 out of 16,291).</li>
#     <li>Let's try separating them out by decade and see what that looks like.</li>
#     </div>

# %%
df['Year'].dtype
# Out:
# dtype('int64')

# %%
df1980s = df.loc[(df.Year >= 1980) & (df.Year < 1990)]
df1990s = df.loc[(df.Year >= 1990) & (df.Year < 2000)]
df2000s = df.loc[(df.Year >= 2000) & (df.Year < 2010)]
df2010s = df.loc[(df.Year >= 2010) & (df.Year < 2020)]

# %%
df1980s['Global_Sales'].plot(kind='box')
plt.show()

# %%
df1990s['Global_Sales'].plot(kind='box')
plt.show()

# %%
df2000s['Global_Sales'].plot(kind='box')
plt.show()

# %%
df2010s['Global_Sales'].plot(kind='box')
plt.show()

# %%
plt.violinplot(df1980s['Global_Sales'])
plt.show()

# %%
plt.violinplot(df1990s['Global_Sales'])
plt.show()

# %%
plt.violinplot(df2000s['Global_Sales'])
plt.show()

# %%
plt.violinplot(df2010s['Global_Sales'])
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>The violinplots do a better job of illustrating this phenomenon. Let's try with North American sales.</li>
#     </div>

# %%
plt.violinplot(df1980s['NA_Sales'])
plt.show()

# %%
plt.violinplot(df1990s['NA_Sales'])
plt.show()

# %%
plt.violinplot(df2000s['NA_Sales'])
plt.show()

# %%
plt.violinplot(df2010s['NA_Sales'])
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>Pretty much the same result. It seems that with video games you either have a hit franchise or hope to break even on the cost of development.</li>
#     </div>

# %% [markdown]
# ### 5d) Platform and Game Sales Performance

# %%
platform_sales = df.groupby(['Platform'])['Global_Sales'].sum().sort_values(ascending=False).reset_index().head(10)
platform_sales
# Out:
#   Platform  Global_Sales
# 0      PS2       1233.46
# 1     X360        969.60
# 2      PS3        949.35
# 3      Wii        909.81
# 4       DS        818.91
# 5       PS        727.39
# 6      GBA        305.62
# 7      PSP        291.71
# 8      PS4        278.10
# 9       PC        254.70

# %%
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
plt.bar(platform_sales['Platform'], platform_sales['Global_Sales'], width=0.8, edgecolor='k')
plt.xticks(fontsize=11)
plt.xlabel('Platform', fontsize=14)
plt.ylabel('Sales (in Millions of $)', fontsize=14)
plt.title('Total Sales by Platform (1980-2020)', fontsize=22)
plt.tight_layout()
plt.show()

# %%
comp_platform = df[['Platform', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
comp_plat_map = comp_platform.groupby(by=['Platform']).sum()

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.3)
sns.heatmap(comp_plat_map, annot=True, fmt='.1f')

plt.xlabel('Region')
plt.xticks(fontsize=14)
plt.yticks(fontsize=13)
plt.title('Comparison of Sales across Regions and Platforms', fontsize=28)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>Even though Playstation 2 and Nintendo DS had a similar number of games released the PS2 outsold it by about &dollar;400 Million.</li>
#     <li>No other platform had over &dollar;1 Billion in gross sales.</li>
#     <ul>Region-wise sales performance is as follows:
#     <li>Xbox 360 actually outsold the Playstation 2 in North America!</li>
#     <li>Nintendo DS and Playstation 1 outsold the PS2 in Japan.</li>
#     <li>In other regions, Playstation 3 and Playstation 2 were the highest selling consoles</li>
#         </ul>
# </div>

# %%
top_games = df.groupby(['Name'])['Global_Sales'].max().sort_values(ascending=False).reset_index().head(10)
top_games
# Out:
#                         Name  Global_Sales
# 0                 Wii Sports         82.74
# 1          Super Mario Bros.         40.24
# 2             Mario Kart Wii         35.82
# 3          Wii Sports Resort         33.00
# 4   Pokemon Red/Pokemon Blue         31.37
# 5                     Tetris         30.26
# 6      New Super Mario Bros.         30.01
# 7                   Wii Play         29.02
# 8  New Super Mario Bros. Wii         28.62
# 9                  Duck Hunt         28.31

# %%
plt.rcParams.update({'axes.facecolor':'gold'})
plt.figure(figsize=(12,6), facecolor='gold')
plt.bar(top_games['Name'], top_games['Global_Sales'], width=0.8, edgecolor='k')
plt.xticks(fontsize=11, rotation=62)
plt.xlabel('Game Title', fontsize=14)
plt.ylabel('Sales (in Millions of $)', fontsize=14)
plt.title('Top Selling Games (1980-2020)', fontsize=22)
plt.show()

# %% [markdown]
# ### 5e) Region Sales Performance

# %%
top_sales_reg = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
top_sales_reg = top_sales_reg.sum().reset_index()
top_sales_reg = top_sales_reg.rename(columns={'index':'Region', 0:'Sales'})
top_sales_reg
# Out:
#         Region   Sales
# 0     NA_Sales 4327.65
# 1     EU_Sales 2406.69
# 2     JP_Sales 1284.27
# 3  Other_Sales  788.91

# %%
labels = top_sales_reg['Region']
size = top_sales_reg['Sales']

# %%
top_sales_fig = top_sales_reg.groupby(['Region'])['Sales'].sum().sort_values(ascending=False).head(10)
top_sales_fig
# Out:
# Region
# NA_Sales      4327.65
# EU_Sales      2406.69
# JP_Sales      1284.27
# Other_Sales    788.91
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12,6), facecolor='gold')
top_sales_fig.plot(kind='bar', width=0.6, edgecolor='k')
plt.xlabel('Region', fontsize=16)
plt.ylabel('Sales (in Millions of $)', fontsize=16)
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize=14)
plt.title('Total Global Sales (1980-2020)', fontsize=22)
#plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,8), facecolor='gold')
colors = ['deepskyblue', 'dodgerblue', 'lightskyblue', 'royalblue', 'cornflowerblue']
plt.pie(size, labels=labels, colors=colors, autopct='%1.2f%%', pctdistance=.8, startangle=90)
plt.title('Sales by Region (1980-2020)', fontsize=22)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>The North American video game market is by far the largest and most valuable. North Americans spent nearly double what Europeans did on video games and nearly 4x what the Japanese did.</li>
#     <li>North America makes up nearly half of all video game sales.</li>
#     </div>

# %%
top_sales_yearGB = df.groupby(['Year'])['Global_Sales'].sum().sort_values(ascending=False).head(5)
top_sales_yearGB
# Out:
# Year
# 2008   678.90
# 2009   667.30
# 2007   609.92
# 2010   600.29
# 2006   521.04
# Name: Global_Sales, dtype: float64

# %%
plt.figure(figsize=(12,6), facecolor='gold')
top_sales_yearGB.plot(kind='bar', width=0.6, edgecolor='k')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sales (in Millions of $)', fontsize=14)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.title('Top 5 Grossing Years (Global)', fontsize=22)
plt.tight_layout()
plt.show()

# %%
top_sales_yearNA = df.groupby(['Year'])['NA_Sales'].sum().sort_values(ascending=False).head(5)
top_sales_yearNA
# Out:
# Year
# 2008   351.44
# 2009   338.85
# 2007   311.18
# 2010   304.24
# 2006   263.12
# Name: NA_Sales, dtype: float64

# %%
plt.figure(figsize=(12,6), facecolor='gold')
top_sales_yearNA.plot(kind='bar', width=0.6, edgecolor='k')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sales (in Millions of $)', fontsize=14)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.title('Top 5 Grossing Years (North America)', fontsize=22)
plt.tight_layout()
plt.show()

# %%
top_sales_yearEU = df.groupby(['Year'])['EU_Sales'].sum().sort_values(ascending=False).head(5)
top_sales_yearEU
# Out:
# Year
# 2009   191.59
# 2008   184.40
# 2010   176.57
# 2011   167.31
# 2007   160.18
# Name: EU_Sales, dtype: float64

# %%
plt.figure(figsize=(12,6), facecolor='gold')
top_sales_yearEU.plot(kind='bar', width=0.6, edgecolor='k')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sales (in Millions of $)', fontsize=14)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.title('Top 5 Grossing Years (Europe)', fontsize=22)
plt.tight_layout()
plt.show()

# %%
top_sales_yearJP = df.groupby(['Year'])['JP_Sales'].sum().sort_values(ascending=False).head(5)
top_sales_yearJP
# Out:
# Year
# 2006   73.73
# 2009   61.89
# 2007   60.29
# 2008   60.26
# 2010   59.49
# Name: JP_Sales, dtype: float64

# %%
plt.figure(figsize=(12,6), facecolor='gold')
top_sales_yearJP.plot(kind='bar', width=0.6, edgecolor='k')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sales (in Millions of $)', fontsize=14)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.title('Top 5 Grossing Years (Japan)', fontsize=22)
plt.tight_layout()
plt.show()

# %%
top_sales_yearOT = df.groupby(['Year'])['Other_Sales'].sum().sort_values(ascending=False).head(5)
top_sales_yearOT
# Out:
# Year
# 2008   82.39
# 2007   77.58
# 2009   74.77
# 2010   59.90
# 2006   54.43
# Name: Other_Sales, dtype: float64

# %%
plt.figure(figsize=(12,6), facecolor='gold')
top_sales_yearOT.plot(kind='bar', width=0.6, edgecolor='k')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sales (in Millions of $)', fontsize=14)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.title('Top 5 Grossing Years (Rest of World)', fontsize=22)
#plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Summary of Findings</strong>
#     <li>The mid- to late-2000s and beginning of the 2010s were the highest grossing years across the world.</li>
#     <li>During these years, the world spent an average of about &dollar;6 Billion on video games.</li>
#     </div>
